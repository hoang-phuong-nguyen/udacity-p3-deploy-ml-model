# %%
import pandas as pd
import hydra
from hydra.utils import to_absolute_path
from omegaconf import DictConfig

from starter.ml.data import clean_data, process_data
from starter.ml.model import train_model, inference, compute_model_metrics

# %%
# load raw data
data_path = to_absolute_path("data/census.csv")
raw_df =  pd.read_csv(data_path, skipinitialspace=True)
print(f'Raw data shape: {raw_df.shape}')
raw_df.head()
# Out:
# Raw data shape: (32561, 15)
#    age         workclass   fnlgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# clean data
clean_df = clean_data(raw_df)
print(f'Clean data shape: {clean_df.shape}')
clean_df.head()
# Out:
# Clean data shape: (30139, 15)
#    age         workclass   fnlgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
from sklearn.model_selection import train_test_split

# split train, test data
train, test = train_test_split(clean_df, test_size=0.2)
print(f'Training set shape: {train.shape}')
print(f'Test set shape: {test.shape}')
# Out:
# Training set shape: (24111, 15)
# Test set shape: (6028, 15)

# %%
# select features
cat_features = [
    "workclass",
    "education",
    "marital-status",
    "occupation",
    "relationship",
    "race",
    "sex",
    "native-country",
]

# one hot enconding
X_train, y_train, encoder_train, lb_train = process_data(
    X=train,
    categorical_features=cat_features,
    label="salary",
    training=True)
print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')

X_test, y_test, _, _ = process_data(
    X=test,
    categorical_features=cat_features,
    label="salary",
    training=False,
    encoder=encoder_train,
    lb=lb_train)
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (24111, 104)
# y_train shape: (24111,)
# X_test shape: (6028, 104)
# y_test shape: (6028,)

# %%
from sklearn.model_selection import train_test_split
import pickle

from starter.ml.data import process_data
from starter.ml.model import inference, compute_model_metrics

df =  pd.read_csv("data/census.csv", skipinitialspace=True)
_, test = train_test_split(df, test_size=0.2)
    
with open("model/knn_model.pkl", 'rb') as f:
    model = pickle.load(f)

with open("model/encoder.pkl", 'rb') as f:
    encoder = pickle.load(f)

with open("model/lb.pkl", 'rb') as f:
    lb = pickle.load(f)

# %%
feature = "education"
cat_features = [
        "workclass",
        "education",
        "marital-status",
        "occupation",
        "relationship",
        "race",
        "sex",
        "native-country",
    ]

# %%
test[feature].unique()
# Out:
# array(['HS-grad', 'Some-college', 'Bachelors', '12th', 'Masters',
#        '5th-6th', '10th', 'Assoc-acdm', 'Prof-school', 'Assoc-voc', '9th',
#        '11th', '7th-8th', '1st-4th', 'Doctorate', 'Preschool'],
#       dtype=object)

# %%
cls = 'HS-grad'
df_slice = test[test[feature]==cls]
# encode data
X_test, y_test, _, _ = process_data(
    X=df_slice,
    categorical_features=cat_features,
    encoder=encoder,
    lb=lb,
    training=False)

# %%
df_slice
# Out:
#        age         workclass   fnlgt education  education-num  \
# 19693   43           Private   96483   HS-grad              9
# 13493   64                 ?  193043   HS-grad              9
# 27879   28           Private  261725   HS-grad              9
# 25349   24           Private  433330   HS-grad              9
# 20861   55  Self-emp-not-inc  126117   HS-grad              9
# ...    ...               ...     ...       ...            ...
# 19306   49  Self-emp-not-inc  173411   HS-grad              9
# 14830   60      Self-emp-inc  376133   HS-grad              9
# 18188   32      Self-emp-inc   45796   HS-grad              9
# 28029   32  Self-emp-not-inc  189461   HS-grad              9
# 28018   30           Private  293936   HS-grad              9
#
#            marital-status         occupation   relationship  \
# 19693            Divorced      Other-service      Own-child
# 13493  Married-civ-spouse                  ?        Husband
# 27879       Never-married      Other-service      Unmarried
# 25349            Divorced  Machine-op-inspct  Not-in-family
# 20861             Widowed              Sales  Not-in-family
# ...                   ...                ...            ...
# 19306            Divorced              Sales  Not-in-family
# 14830  Married-civ-spouse       Adm-clerical           Wife
# 18188  Married-civ-spouse    Exec-managerial        Husband
# 28029       Never-married      Other-service  Not-in-family
# 28018       Never-married      Other-service  Not-in-family
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 19693  Asian-Pac-Islander  Female             0             0              40
# 13493               White    Male             0             0              40
# 27879               White  Female             0             0              40
# 25349               White    Male             0             0              40
# 20861               White    Male             0             0              40
# ...                   ...     ...           ...           ...             ...
# 19306               White    Male             0             0              40
# 14830               White  Female         15024             0              15
# 18188               White    Male             0             0              45
# 28029               White  Female             0             0              60
# 28018               White    Male             0             0              50
#
#       native-country salary
# 19693          South  <=50K
# 13493  United-States  <=50K
# 27879         Mexico  <=50K
# 25349  United-States  <=50K
# 20861  United-States  <=50K
# ...              ...    ...
# 19306  United-States  <=50K
# 14830  United-States   >50K
# 18188  United-States  <=50K
# 28029  United-States  <=50K
# 28018              ?  <=50K
#
# [2122 rows x 15 columns]

# %%
feature = "education"


X_test, y_test, _, _ = process_data(
        X=test,
        categorical_features=cat_features,
        encoder=encoder,
        lb=lb,
        training=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 feature = "education"
# ----> 2 X_test, y_test, _, _ = process_data(
#       3         X=test,
#       4         categorical_features=[feature],
#       5         encoder=encoder,
#       6         lb=lb,
#       7         training=False)
#
# File ~/Documents/04-Courses/2023/01-Udacity_Machine_Learning DevOps_Engineer/P3-deploy-ml-model/starter/ml/data.py:67, in process_data(X, categorical_features, label, training, encoder, lb)
#      65     y = lb.fit_transform(y.values).ravel()
#      66 else:
# ---> 67     X_categorical = encoder.transform(X_categorical)
#      68     try:
#      69         y = lb.transform(y.values).ravel()
#
# File ~/miniconda3/envs/p3_mlops/lib/python3.8/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/miniconda3/envs/p3_mlops/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py:917, in OneHotEncoder.transform(self, X)
#     912 # validation of X happens in _check_X called by _transform
#     913 warn_on_unknown = self.drop is not None and self.handle_unknown in {
#     914     "ignore",
#     915     "infrequent_if_exist",
#     916 }
# --> 917 X_int, X_mask = self._transform(
#     918     X,
#     919     handle_unknown=self.handle_unknown,
#     920     force_all_finite="allow-nan",
#     921     warn_on_unknown=warn_on_unknown,
#     922 )
#     923 self._map_infrequent_categories(X_int, X_mask)
#     925 n_samples, n_features = X_int.shape
#
# File ~/miniconda3/envs/p3_mlops/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py:155, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown)
#     151 def _transform(
#     152     self, X, handle_unknown="error", force_all_finite=True, warn_on_unknown=False
#     153 ):
#     154     self._check_feature_names(X, reset=False)
# --> 155     self._check_n_features(X, reset=False)
#     156     X_list, n_samples, n_features = self._check_X(
#     157         X, force_all_finite=force_all_finite
#     158     )
#     160     X_int = np.zeros((n_samples, n_features), dtype=int)
#
# File ~/miniconda3/envs/p3_mlops/lib/python3.8/site-packages/sklearn/base.py:389, in BaseEstimator._check_n_features(self, X, reset)
#     386     return
#     388 if n_features != self.n_features_in_:
# --> 389     raise ValueError(
#     390         f"X has {n_features} features, but {self.__class__.__name__} "
#     391         f"is expecting {self.n_features_in_} features as input."
#     392     )
#
# ValueError: X has 1 features, but OneHotEncoder is expecting 8 features as input.

# %%
X_test
# Out:
# array([[3.60000e+01, 1.81322e+05, 1.30000e+01, ..., 1.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [4.10000e+01, 1.18212e+05, 1.30000e+01, ..., 1.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [3.30000e+01, 1.12941e+05, 9.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        ...,
#        [3.40000e+01, 1.82714e+05, 1.30000e+01, ..., 1.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [3.90000e+01, 1.17683e+05, 9.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [2.70000e+01, 2.59873e+05, 9.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 0.00000e+00]])

# %%
# train model
model = train_model(X_train, y_train, num_nb=50)

# %%
# predict
y_pred = inference(model, X_test)

# evaluate model 
precision, recall, f1 = compute_model_metrics(y_test, y_pred)
print(f'>> Precision: {precision}')
print(f'>> Recall: {recall}')
print(f'>> F1: {f1}')
# Out:
# >> Precision: 0.9578059071729957
# >> Recall: 0.15275908479138628
# >> F1: 0.2634939059779454
